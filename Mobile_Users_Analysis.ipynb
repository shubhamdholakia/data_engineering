# %%
import pandas as pd 
users_activity = pd.read_csv('User_activity.txt')

# %%
# Using transpose to get column names which were previously indexes
ab = users_activity.head().transpose()

# %%
ab.head()
# Out:
#                      0                        1         2
# Unnamed: 0   device_id                 app_name   minutes
# 0           B-52-23845    Snapchat (Mobile App)   27.9342
# 1           B-52-16587   Pinterest (Mobile App)   14.6664
# 2           B-52-36461    Facebook (Mobile App)  439.7652
# 3           B-52-29089  Yahoo Mail (Mobile App)  900.6606

# %%
 
pd.DataFrame(ab)
# Out:
#                      0                        1                   2
# Unnamed: 0   device_id                 app_name             minutes
# 0           B-52-23845    Snapchat (Mobile App)             27.9342
# 1           B-52-16587   Pinterest (Mobile App)             14.6664
# 2           B-52-36461    Facebook (Mobile App)            439.7652
# 3           B-52-29089  Yahoo Mail (Mobile App)            900.6606
# ...                ...                      ...                 ...
# 22443       B-52-29089  Yahoo Mail (Mobile App)            900.6606
# 22444       B-52-13395     Netflix (Mobile App)  1.1340000000000001
# 22445        B-52-8702     GroupMe (Mobile App)            343.5264
# 22446       B-52-50977   Instagram (Mobile App)              0.9072
# 22447       B-52-48431     YouTube (Mobile App)            994.6692
#
# [22449 rows x 3 columns]

# %%
# Replacing the default column names like 0,1,2 by expected column names 
ab.rename(columns = {0:'device_id',1:'app_name',2:'minutes'})
# Out:
#              device_id                 app_name             minutes
# Unnamed: 0   device_id                 app_name             minutes
# 0           B-52-23845    Snapchat (Mobile App)             27.9342
# 1           B-52-16587   Pinterest (Mobile App)             14.6664
# 2           B-52-36461    Facebook (Mobile App)            439.7652
# 3           B-52-29089  Yahoo Mail (Mobile App)            900.6606
# ...                ...                      ...                 ...
# 22443       B-52-29089  Yahoo Mail (Mobile App)            900.6606
# 22444       B-52-13395     Netflix (Mobile App)  1.1340000000000001
# 22445        B-52-8702     GroupMe (Mobile App)            343.5264
# 22446       B-52-50977   Instagram (Mobile App)              0.9072
# 22447       B-52-48431     YouTube (Mobile App)            994.6692
#
# [22449 rows x 3 columns]

# %%
#Dropping 1st index which was the row .. 
ab.drop(index = ab.index[0],axis=0,inplace = True)

# %%
ab.head()
# Out:
#             0                        1         2
# 0  B-52-23845    Snapchat (Mobile App)   27.9342
# 1  B-52-16587   Pinterest (Mobile App)   14.6664
# 2  B-52-36461    Facebook (Mobile App)  439.7652
# 3  B-52-29089  Yahoo Mail (Mobile App)  900.6606
# 4  B-52-14212     Netflix (Mobile App)   17.3502

# %%
ab.describe()
# Out:
#                  0                         1       2
# count        22448                     22448   21700
# unique        2774                        21   13219
# top     B-52-13395  Google Play (Mobile App)  0.1512
# freq            16                      2761      57

# %%
# creating a df dataframe and renaming the columns as we can see it ab.describe() rename didnt work properly .. so created df
df = ab.rename(columns = {0:'device_id',1:'app_name',2:'minutes'})

# %%
df.head()
# Out:
#     device_id                 app_name   minutes
# 0  B-52-23845    Snapchat (Mobile App)   27.9342
# 1  B-52-16587   Pinterest (Mobile App)   14.6664
# 2  B-52-36461    Facebook (Mobile App)  439.7652
# 3  B-52-29089  Yahoo Mail (Mobile App)  900.6606
# 4  B-52-14212     Netflix (Mobile App)   17.3502

# %%
df.describe()
# Out:
#          device_id                  app_name minutes
# count        22448                     22448   21700
# unique        2774                        21   13219
# top     B-52-13395  Google Play (Mobile App)  0.1512
# freq            16                      2761      57

# %%
# performing basic checks
df.head().duplicated().sum()
# Out:
# 0

# %%
df.head().isnull().sum()
# Out:
# device_id    0
# app_name     0
# minutes      0
# dtype: int64

# %%
# Got data from device demographics file in device_demo variable
device_demo = pd.read_csv('device_demographics.csv ')

# %%
device_demo.head()
# Out:
#     device_id  gender_id
# 0  B-52-23845        2.0
# 1  B-52-16587        1.0
# 2  B-52-36461        2.0
# 3  B-52-29089        2.0
# 4  B-52-14212        2.0

# %%
device_demo.duplicated().sum()
# Out:
# 0

# %%
device_demo.isnull().sum()
# Out:
# device_id     0
# gender_id    98
# dtype: int64

# %%
publisher = pd.read_csv('publishers.csv')

# %%
publisher.head()
# Out:
#                             app_name        Publisher
# 0               Walmart (Mobile App)         Wal-Mart
# 1        Microsoft Word (Mobile App)  Microsoft Sites
# 2  Sam's Club Scan & Go (Mobile App)         Wal-Mart
# 3             Pinterest (Mobile App)        Pinterest
# 4               YouTube (Mobile App)     Google Sites

# %%
# found nulls here which we will handle later as per as the instructions
publisher.isnull().sum()
# Out:
# app_name     0
# Publisher    0
# dtype: int64

# %%
# also found duplicates in publisher file
publisher.duplicated().sum()
# Out:
# 2

# %%
publisher.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# dtype: bool

# %%
publisher.iloc[21]
# Out:
# app_name     Walmart (Mobile App)
# Publisher                Wal-Mart
# Name: 21, dtype: object

# %%
publisher.iloc[22]
# Out:
# app_name     Microsoft Word (Mobile App)
# Publisher                Microsoft Sites
# Name: 22, dtype: object

# %%
 publisher.describe()
# Out:
#                     app_name Publisher
# count                     23        23
# unique                    21         9
# top     Walmart (Mobile App)  Wal-Mart
# freq                       2         4

# %%
publisher.head(23)
# Out:
#                                       app_name        Publisher
# 0                         Walmart (Mobile App)         Wal-Mart
# 1                  Microsoft Word (Mobile App)  Microsoft Sites
# 2            Sam's Club Scan & Go (Mobile App)         Wal-Mart
# 3                       Pinterest (Mobile App)        Pinterest
# 4                         YouTube (Mobile App)     Google Sites
# 5                         Netflix (Mobile App)     Netflix Inc.
# 6                          Tumblr (Mobile App)             Oath
# 7              Facebook Messenger (Mobile App)         Facebook
# 8                          Kindle (Mobile App)     Amazon Sites
# 9                         GroupMe (Mobile App)  Microsoft Sites
# 10                     Sam's Club (Mobile App)         Wal-Mart
# 11                    Google Play (Mobile App)     Google Sites
# 12                     Yahoo Mail (Mobile App)             Oath
# 13                        Outlook (Mobile App)  Microsoft Sites
# ...

# %%
publisher[publisher.duplicated()]
# Out:
#                        app_name        Publisher
# 21         Walmart (Mobile App)         Wal-Mart
# 22  Microsoft Word (Mobile App)  Microsoft Sites

# %%
publisher.loc[0]
# Out:
# app_name     Walmart (Mobile App)
# Publisher                Wal-Mart
# Name: 0, dtype: object

# %%
publisher.loc[21]
# Out:
# app_name     Walmart (Mobile App)
# Publisher                Wal-Mart
# Name: 21, dtype: object

# %%
publisher.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   app_name   23 non-null     object
#  1   Publisher  23 non-null     object
# dtypes: object(2)
# memory usage: 496.0+ bytes

# %%
# Dropping app_name = Walmart Publisher = 'Wal-Mart' and dropping app_name = 'Microsoft Word (Mobile App)' and Publisher = Microsoft Sites which are duplicate
publisher.drop_duplicates(keep = 'first')
# Out:
#                                       app_name        Publisher
# 0                         Walmart (Mobile App)         Wal-Mart
# 1                  Microsoft Word (Mobile App)  Microsoft Sites
# 2            Sam's Club Scan & Go (Mobile App)         Wal-Mart
# 3                       Pinterest (Mobile App)        Pinterest
# 4                         YouTube (Mobile App)     Google Sites
# 5                         Netflix (Mobile App)     Netflix Inc.
# 6                          Tumblr (Mobile App)             Oath
# 7              Facebook Messenger (Mobile App)         Facebook
# 8                          Kindle (Mobile App)     Amazon Sites
# 9                         GroupMe (Mobile App)  Microsoft Sites
# 10                     Sam's Club (Mobile App)         Wal-Mart
# 11                    Google Play (Mobile App)     Google Sites
# 12                     Yahoo Mail (Mobile App)             Oath
# 13                        Outlook (Mobile App)  Microsoft Sites
# ...

# %%
# Checking no of brands
df.groupby('app_name').first().count()
# Out:
# device_id    21
# minutes      21
# dtype: int64

# %%
df.head()
# Out:
#     device_id                 app_name   minutes
# 0  B-52-23845    Snapchat (Mobile App)   27.9342
# 1  B-52-16587   Pinterest (Mobile App)   14.6664
# 2  B-52-36461    Facebook (Mobile App)  439.7652
# 3  B-52-29089  Yahoo Mail (Mobile App)  900.6606
# 4  B-52-14212     Netflix (Mobile App)   17.3502

# %%
# inner joining all the 3 one after one after removing duplicates from publisher
df1 = pd.merge(df,publisher,on = 'app_name',how = 'inner')

# %%
df1.head()
# Out:
#     device_id               app_name    minutes      Publisher
# 0  B-52-23845  Snapchat (Mobile App)    27.9342  Snapchat, Inc
# 1   B-52-6821  Snapchat (Mobile App)     17.199  Snapchat, Inc
# 2  B-52-21945  Snapchat (Mobile App)   181.7046  Snapchat, Inc
# 3  B-52-24149  Snapchat (Mobile App)   133.3962  Snapchat, Inc
# 4  B-52-28462  Snapchat (Mobile App)  1252.7676  Snapchat, Inc

# %%
# found duplicates will deal with it later
df1.duplicated().sum()
# Out:
# 975

# %%
df1.count()
# Out:
# device_id    23415
# app_name     23415
# minutes      22632
# Publisher    23415
# dtype: int64

# %%
device_demo.count()
# Out:
# device_id    2774
# gender_id    2676
# dtype: int64

# %%
device_demo.isnull().sum()
# Out:
# device_id     0
# gender_id    98
# dtype: int64

# %%
# Just confirming the count of the join on group by on device_id matches device demographics
df1.groupby('device_id').first()
# Out:
#                               app_name    minutes      Publisher
# device_id
# B-52-10013       Snapchat (Mobile App)    16.1028  Snapchat, Inc
# B-52-10032       Facebook (Mobile App)     1.4742       Facebook
# B-52-10051       Facebook (Mobile App)  7955.2368       Facebook
# B-52-1007   Google Search (Mobile App)     6.9174   Google Sites
# B-52-10070       Facebook (Mobile App)  9837.1098       Facebook
# ...                                ...        ...            ...
# B-52-9918       Pinterest (Mobile App)    52.4286      Pinterest
# B-52-9937       Pinterest (Mobile App)     91.665      Pinterest
# B-52-9956        Snapchat (Mobile App)   120.0528  Snapchat, Inc
# B-52-9975        Facebook (Mobile App)    69.4386       Facebook
# B-52-9994        Snapchat (Mobile App)     8.7696  Snapchat, Inc
#
# [2774 rows x 3 columns]

# %%
# Joining device demographics and the minutes text file
df2 = pd.merge(df1,device_demo,on = 'device_id',how = 'inner')

# %%
df2.head()
# Out:
#     device_id                    app_name  minutes      Publisher  gender_id
# 0  B-52-23845       Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 1  B-52-23845       Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 2  B-52-23845      Pinterest (Mobile App)   5.5188      Pinterest        2.0
# 3  B-52-23845      Instagram (Mobile App)  867.132       Facebook        2.0
# 4  B-52-23845  Google Search (Mobile App)  236.817   Google Sites        2.0

# %%
df2.duplicated().sum()
# Out:
# 975

# %%
df2[df2.duplicated()]
# Out:
#         device_id                     app_name             minutes  \
# 1      B-52-23845        Snapchat (Mobile App)             27.9342
# 21      B-52-6821  Microsoft Word (Mobile App)             10.2816
# 23      B-52-6821         Walmart (Mobile App)             10.0548
# 57     B-52-28462         Walmart (Mobile App)            144.8496
# 89      B-52-3496         Walmart (Mobile App)              5.1786
# ...           ...                          ...                 ...
# 23315  B-52-10735         Walmart (Mobile App)            147.0042
# 23365  B-52-36765         Walmart (Mobile App)             50.3118
# 23371  B-52-28994         Walmart (Mobile App)  309.77099999999996
# 23379  B-52-45923         Walmart (Mobile App)                 NaN
# 23400  B-52-45220  Microsoft Word (Mobile App)              8.5806
#
#              Publisher  gender_id
# 1        Snapchat, Inc        2.0
# 21     Microsoft Sites        2.0
# 23            Wal-Mart        2.0
# ...

# %%
df2.count()
# Out:
# device_id    23415
# app_name     23415
# minutes      22632
# Publisher    23415
# gender_id    22587
# dtype: int64

# %%
# dropped the duplicates here after the joins ... 
df2.drop_duplicates(keep = 'first',inplace = True)

# %%
df2.head()
# Out:
#     device_id                    app_name  minutes      Publisher  gender_id
# 0  B-52-23845       Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 2  B-52-23845      Pinterest (Mobile App)   5.5188      Pinterest        2.0
# 3  B-52-23845      Instagram (Mobile App)  867.132       Facebook        2.0
# 4  B-52-23845  Google Search (Mobile App)  236.817   Google Sites        2.0
# 5  B-52-23845        YouTube (Mobile App)  69.6276   Google Sites        2.0

# %%
# after dropping thw rows we reset the index as they r not in order 
df2.reset_index(inplace = True , drop = True)

# %%
df2.head()
# Out:
#     device_id                    app_name  minutes      Publisher  gender_id
# 0  B-52-23845       Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 1  B-52-23845      Pinterest (Mobile App)   5.5188      Pinterest        2.0
# 2  B-52-23845      Instagram (Mobile App)  867.132       Facebook        2.0
# 3  B-52-23845  Google Search (Mobile App)  236.817   Google Sites        2.0
# 4  B-52-23845        YouTube (Mobile App)  69.6276   Google Sites        2.0

# %%
df2.count()
# Out:
# device_id    22440
# app_name     22440
# minutes      21692
# Publisher    22440
# gender_id    21645
# dtype: int64

# %%
# Creating lookup table_1 after groupby on app_name however this approach didnt work out 
from scipy import stats
lookup_table1 = df2[['app_name','Publisher','gender_id']].groupby('app_name',as_index = False)

# %%
lookup_table1.head()
# Out:
#                                app_name      Publisher  gender_id
# 0                 Snapchat (Mobile App)  Snapchat, Inc        2.0
# 1                Pinterest (Mobile App)      Pinterest        2.0
# 2                Instagram (Mobile App)       Facebook        2.0
# 3            Google Search (Mobile App)   Google Sites        2.0
# 4                  YouTube (Mobile App)   Google Sites        2.0
# ...                                 ...            ...        ...
# 1927        Yahoo Newsroom (Mobile App)           Oath        1.0
# 2801            Sam's Club (Mobile App)       Wal-Mart        2.0
# 2952  Sam's Club Scan & Go (Mobile App)       Wal-Mart        2.0
# 2953            Sam's Club (Mobile App)       Wal-Mart        2.0
# 3215  Sam's Club Scan & Go (Mobile App)       Wal-Mart        2.0
#
# [105 rows x 3 columns]

# %%
# Creating gender_id mode lookup table and testing it here first
import numpy as np
df2.groupby(['app_name','Publisher'],as_index=False).agg({'gender_id':pd.Series.mode})
# Out:
#                                       app_name        Publisher  gender_id
# 0                   Amazon Mobile (Mobile App)     Amazon Sites        2.0
# 1   Amazon Music with Prime Music (Mobile App)     Amazon Sites        2.0
# 2                        Facebook (Mobile App)         Facebook        2.0
# 3              Facebook Messenger (Mobile App)         Facebook        2.0
# 4                     Google Play (Mobile App)     Google Sites        2.0
# 5                   Google Search (Mobile App)     Google Sites        2.0
# 6                         GroupMe (Mobile App)  Microsoft Sites        2.0
# 7                       Instagram (Mobile App)         Facebook        2.0
# 8                          Kindle (Mobile App)     Amazon Sites        2.0
# 9                  Microsoft Word (Mobile App)  Microsoft Sites        2.0
# 10                        Netflix (Mobile App)     Netflix Inc.        2.0
# ...

# %%
# after testing assigned it to variable df3 
df3 = df2.groupby(['app_name','Publisher'],as_index=False).agg({'gender_id':pd.Series.mode})

# %%
df3
# Out:
#                                       app_name        Publisher  gender_id
# 0                   Amazon Mobile (Mobile App)     Amazon Sites        2.0
# 1   Amazon Music with Prime Music (Mobile App)     Amazon Sites        2.0
# 2                        Facebook (Mobile App)         Facebook        2.0
# 3              Facebook Messenger (Mobile App)         Facebook        2.0
# 4                     Google Play (Mobile App)     Google Sites        2.0
# 5                   Google Search (Mobile App)     Google Sites        2.0
# 6                         GroupMe (Mobile App)  Microsoft Sites        2.0
# 7                       Instagram (Mobile App)         Facebook        2.0
# 8                          Kindle (Mobile App)     Amazon Sites        2.0
# 9                  Microsoft Word (Mobile App)  Microsoft Sites        2.0
# 10                        Netflix (Mobile App)     Netflix Inc.        2.0
# ...

# %%
# created a file for gender mode by app_name as lookup_table_1.csv
df3.to_csv('lookup_table_1.csv',index = False)

# %%
# create a lookup table for median minutes over app_name
df4 = df2.groupby(['app_name','Publisher'],as_index=False).agg({'minutes':pd.Series.median})

# %%
df4
# Out:
#                                       app_name        Publisher    minutes
# 0                   Amazon Mobile (Mobile App)     Amazon Sites    47.1555
# 1   Amazon Music with Prime Music (Mobile App)     Amazon Sites    34.3980
# 2                        Facebook (Mobile App)         Facebook  2764.6542
# 3              Facebook Messenger (Mobile App)         Facebook  1349.6490
# 4                     Google Play (Mobile App)     Google Sites    57.6639
# 5                   Google Search (Mobile App)     Google Sites   119.8638
# 6                         GroupMe (Mobile App)  Microsoft Sites    64.6758
# 7                       Instagram (Mobile App)         Facebook   247.2498
# 8                          Kindle (Mobile App)     Amazon Sites    25.4394
# 9                  Microsoft Word (Mobile App)  Microsoft Sites    11.6046
# 10                        Netflix (Mobile App)     Netflix Inc.    79.4934
# ...

# %%
# created a  lookup table 2 file as lookup_table_minutes
df4.to_csv('lookup_table_minutes.csv',index = False)

# %%
df2.isnull().sum()
# Out:
# device_id      0
# app_name       0
# minutes      748
# Publisher      0
# gender_id    795
# dtype: int64

# %%
# Merged the o/p of 3 joins with lookup_table_1
df5 = pd.merge(df2,df3,on = ['app_name','Publisher'],how = 'left')

# %%
# performed basic checks 
df5.duplicated().sum()
# Out:
# 0

# %%
df5.isnull()
# Out:
#        device_id  app_name  minutes  Publisher  gender_id_x  gender_id_y
# 0          False     False    False      False        False        False
# 1          False     False    False      False        False        False
# 2          False     False    False      False        False        False
# 3          False     False    False      False        False        False
# 4          False     False    False      False        False        False
# ...          ...       ...      ...        ...          ...          ...
# 22435      False     False    False      False        False        False
# 22436      False     False    False      False        False        False
# 22437      False     False    False      False        False        False
# 22438      False     False    False      False        False        False
# 22439      False     False    False      False        False        False
#
# [22440 rows x 6 columns]

# %%
# Finding nans 
boolean_series = pd.isnull(df5["gender_id_x"])
boolean_series.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: gender_id_x, dtype: bool

# %%
df5[boolean_series]
# Out:
#         device_id                                    app_name    minutes  \
# 43     B-52-28462                       Snapchat (Mobile App)  1252.7676
# 44     B-52-28462                      Pinterest (Mobile App)     5.1786
# 45     B-52-28462                      Instagram (Mobile App)   5376.672
# 46     B-52-28462                  Google Search (Mobile App)  3212.1306
# 47     B-52-28462                        YouTube (Mobile App)   151.0866
# ...           ...                                         ...        ...
# 22308  B-52-52269                        YouTube (Mobile App)   318.4272
# 22309  B-52-52269             Facebook Messenger (Mobile App)     1.0206
# 22310  B-52-52269                    Google Play (Mobile App)   213.4566
# 22311  B-52-52269                  Amazon Mobile (Mobile App)     1.9656
# 22312  B-52-52269  Amazon Music with Prime Music (Mobile App)     2.5326
#
#            Publisher  gender_id_x  gender_id_y
# ...

# %%
df5.head()
# Out:
#     device_id                    app_name  minutes      Publisher  \
# 0  B-52-23845       Snapchat (Mobile App)  27.9342  Snapchat, Inc
# 1  B-52-23845      Pinterest (Mobile App)   5.5188      Pinterest
# 2  B-52-23845      Instagram (Mobile App)  867.132       Facebook
# 3  B-52-23845  Google Search (Mobile App)  236.817   Google Sites
# 4  B-52-23845        YouTube (Mobile App)  69.6276   Google Sites
#
#    gender_id_x  gender_id_y
# 0          2.0          2.0
# 1          2.0          2.0
# 2          2.0          2.0
# 3          2.0          2.0
# 4          2.0          2.0

# %%
df5.loc[df5['gender_id_x']==1]
# Out:
#         device_id                         app_name             minutes  \
# 54     B-52-30153            Snapchat (Mobile App)            387.0342
# 55     B-52-30153            Facebook (Mobile App)           1527.4602
# 56     B-52-30153           Instagram (Mobile App)            117.0288
# 57     B-52-30153       Google Search (Mobile App)             53.1468
# 58     B-52-30153             YouTube (Mobile App)          10694.8296
# ...           ...                              ...                 ...
# 22418  B-52-23674             GroupMe (Mobile App)            212.1336
# 22419  B-52-46892             YouTube (Mobile App)  337.93199999999996
# 22420  B-52-46892  Facebook Messenger (Mobile App)             32.1678
# 22421  B-52-46892         Google Play (Mobile App)              1.5498
# 22429  B-52-19722         Google Play (Mobile App)                 NaN
#
#              Publisher  gender_id_x  gender_id_y
# 54       Snapchat, Inc          1.0          2.0
# ...

# %%
# Filling na with gender_id_y which is the mode of gender across each respective app 
df5['gender_id_x'].fillna(df5['gender_id_y'],inplace = True)

# %%
df5.isnull().sum()
# Out:
# device_id        0
# app_name         0
# minutes        748
# Publisher        0
# gender_id_x      0
# gender_id_y      0
# dtype: int64

# %%
# checked to see if gender_id 1 still exists 
df5.loc[df5['gender_id_x']==1]
# Out:
#         device_id                         app_name             minutes  \
# 54     B-52-30153            Snapchat (Mobile App)            387.0342
# 55     B-52-30153            Facebook (Mobile App)           1527.4602
# 56     B-52-30153           Instagram (Mobile App)            117.0288
# 57     B-52-30153       Google Search (Mobile App)             53.1468
# 58     B-52-30153             YouTube (Mobile App)          10694.8296
# ...           ...                              ...                 ...
# 22418  B-52-23674             GroupMe (Mobile App)            212.1336
# 22419  B-52-46892             YouTube (Mobile App)  337.93199999999996
# 22420  B-52-46892  Facebook Messenger (Mobile App)             32.1678
# 22421  B-52-46892         Google Play (Mobile App)              1.5498
# 22429  B-52-19722         Google Play (Mobile App)                 NaN
#
#              Publisher  gender_id_x  gender_id_y
# 54       Snapchat, Inc          1.0          2.0
# ...

# %%
# Gender_id x has no nulls now
df5.isnull().sum()
# Out:
# device_id        0
# app_name         0
# minutes        748
# Publisher        0
# gender_id_x      0
# gender_id_y      0
# dtype: int64

# %%
# To check if not null in gender_id has been eliminated
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22440 entries, 0 to 22439
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   device_id    22440 non-null  object
#  1   app_name     22440 non-null  object
#  2   minutes      21692 non-null  object
#  3   Publisher    22440 non-null  object
#  4   gender_id_x  22440 non-null  float64
#  5   gender_id_y  22440 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 1.2+ MB

# %%
# this was null previously, has been replaced by 2.0 which is mode of that group ... 
df5.iloc[43]
# Out:
# device_id                 B-52-28462
# app_name       Snapchat (Mobile App)
# minutes                    1252.7676
# Publisher              Snapchat, Inc
# gender_id_x                      2.0
# gender_id_y                      2.0
# Name: 43, dtype: object

# %%
# performing a left join on lookup_table_minutes now 
df6 = pd.merge(df5,df4,on = ['app_name','Publisher'],how = 'left')

# %%
df6.head()
# Out:
#     device_id                    app_name minutes_x      Publisher  \
# 0  B-52-23845       Snapchat (Mobile App)   27.9342  Snapchat, Inc
# 1  B-52-23845      Pinterest (Mobile App)    5.5188      Pinterest
# 2  B-52-23845      Instagram (Mobile App)   867.132       Facebook
# 3  B-52-23845  Google Search (Mobile App)   236.817   Google Sites
# 4  B-52-23845        YouTube (Mobile App)   69.6276   Google Sites
#
#    gender_id_x  gender_id_y  minutes_y
# 0          2.0          2.0   208.6182
# 1          2.0          2.0   104.1390
# 2          2.0          2.0   247.2498
# 3          2.0          2.0   119.8638
# 4          2.0          2.0   209.8656

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22440 entries, 0 to 22439
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   device_id    22440 non-null  object
#  1   app_name     22440 non-null  object
#  2   minutes_x    21692 non-null  object
#  3   Publisher    22440 non-null  object
#  4   gender_id_x  22440 non-null  float64
#  5   gender_id_y  22440 non-null  float64
#  6   minutes_y    22440 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 1.4+ MB

# %%
# same stratergy as previous lookup table
boolean_series2 = pd.isnull(df6['minutes_x'])

# %%
df6[boolean_series2]
# Out:
#         device_id                         app_name minutes_x      Publisher  \
# 23     B-52-21945            Facebook (Mobile App)       NaN       Facebook
# 25     B-52-21945             Netflix (Mobile App)       NaN   Netflix Inc.
# 70     B-52-51851            Snapchat (Mobile App)       NaN  Snapchat, Inc
# 91     B-52-51832  Facebook Messenger (Mobile App)       NaN       Facebook
# 157    B-52-18411         Google Play (Mobile App)       NaN   Google Sites
# ...           ...                              ...       ...            ...
# 22178  B-52-16701             YouTube (Mobile App)       NaN   Google Sites
# 22203  B-52-23636       Google Search (Mobile App)       NaN   Google Sites
# 22253  B-52-26752  Facebook Messenger (Mobile App)       NaN       Facebook
# 22405  B-52-45923             Walmart (Mobile App)       NaN       Wal-Mart
# 22429  B-52-19722         Google Play (Mobile App)       NaN   Google Sites
#
#        gender_id_x  gender_id_y  minutes_y
# ...

# %%
df6['minutes_x'].fillna(df6['minutes_y'],inplace = True)

# %%
df6.head()
# Out:
#     device_id                    app_name minutes_x      Publisher  \
# 0  B-52-23845       Snapchat (Mobile App)   27.9342  Snapchat, Inc
# 1  B-52-23845      Pinterest (Mobile App)    5.5188      Pinterest
# 2  B-52-23845      Instagram (Mobile App)   867.132       Facebook
# 3  B-52-23845  Google Search (Mobile App)   236.817   Google Sites
# 4  B-52-23845        YouTube (Mobile App)   69.6276   Google Sites
#
#    gender_id_x  gender_id_y  minutes_y
# 0          2.0          2.0   208.6182
# 1          2.0          2.0   104.1390
# 2          2.0          2.0   247.2498
# 3          2.0          2.0   119.8638
# 4          2.0          2.0   209.8656

# %%
# checking if data in index 23 which was nan has been replaced by its median 
df6.loc[23]
# Out:
# device_id                 B-52-21945
# app_name       Facebook (Mobile App)
# minutes_x                  2764.6542
# Publisher                   Facebook
# gender_id_x                      2.0
# gender_id_y                      2.0
# minutes_y                  2764.6542
# Name: 23, dtype: object

# %%
# dropping columns derived from lookup tables 
df6.drop(['minutes_y','gender_id_y'],axis = 1,inplace = True)

# %%
# performing checks on df6 ... this is our dataframe where we have created visualization later . 
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22440 entries, 0 to 22439
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   device_id    22440 non-null  object
#  1   app_name     22440 non-null  object
#  2   minutes_x    22440 non-null  object
#  3   Publisher    22440 non-null  object
#  4   gender_id_x  22440 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 1.5+ MB

# %%
df6['minutes_x'].describe()
# Out:
# count     22440.0000
# unique    13239.0000
# top        2764.6542
# freq         98.0000
# Name: minutes_x, dtype: float64

# %%
df6.rename(columns = {'minutes_x':'minutes','gender_id_x':'gender_id'},inplace = True)

# %%
df6.head()
# Out:
#     device_id                    app_name  minutes      Publisher  gender_id
# 0  B-52-23845       Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 1  B-52-23845      Pinterest (Mobile App)   5.5188      Pinterest        2.0
# 2  B-52-23845      Instagram (Mobile App)  867.132       Facebook        2.0
# 3  B-52-23845  Google Search (Mobile App)  236.817   Google Sites        2.0
# 4  B-52-23845        YouTube (Mobile App)  69.6276   Google Sites        2.0

# %%
# Final output for reference
df6.reindex(columns = ['device_id','gender_id','app_name','minutes','Publisher'])
# Out:
#         device_id  gender_id                    app_name             minutes  \
# 0      B-52-23845        2.0       Snapchat (Mobile App)             27.9342
# 1      B-52-23845        2.0      Pinterest (Mobile App)              5.5188
# 2      B-52-23845        2.0      Instagram (Mobile App)             867.132
# 3      B-52-23845        2.0  Google Search (Mobile App)             236.817
# 4      B-52-23845        2.0        YouTube (Mobile App)             69.6276
# ...           ...        ...                         ...                 ...
# 22435  B-52-44289        2.0    Google Play (Mobile App)              0.9072
# 22436  B-52-44080        2.0    Google Play (Mobile App)           2097.8244
# 22437  B-52-44099        2.0    Google Play (Mobile App)            1256.472
# 22438   B-52-1368        2.0    Google Play (Mobile App)             31.9032
# 22439   B-52-1368        2.0  Amazon Mobile (Mobile App)  435.07800000000003
#
#            Publisher
# 0      Snapchat, Inc
# ...

# %%
# wasnt able to group by on minutes so converted it to numeric . 
df6['minutes'] = df6[['minutes']].apply(pd.to_numeric)

# %%
# found median and standard for each respective app from our reference dataframe 
df7 = df6.groupby(['app_name'],as_index = False).agg({'minutes':['median','std']})

# %%
df7.head(25)
# Out:
#                                       app_name    minutes
#                                                    median          std
# 0                   Amazon Mobile (Mobile App)    47.1555   311.223196
# 1   Amazon Music with Prime Music (Mobile App)    34.3980   449.620841
# 2                        Facebook (Mobile App)  2764.6542  3248.020616
# 3              Facebook Messenger (Mobile App)  1349.6490  3039.701650
# 4                     Google Play (Mobile App)    57.6639   548.827380
# 5                   Google Search (Mobile App)   119.8638  1910.343859
# 6                         GroupMe (Mobile App)    64.6758   276.153920
# 7                       Instagram (Mobile App)   247.2498  1480.795910
# 8                          Kindle (Mobile App)    25.4394  1623.650743
# 9                  Microsoft Word (Mobile App)    11.6046    93.392425
# 10                        Netflix (Mobile App)    79.4934  2322.242635
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (app_name, )       21 non-null     object
#  1   (minutes, median)  21 non-null     float64
#  2   (minutes, std)     21 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 672.0+ bytes

# %%
# taking care of indexing as we plan to merge this table later 
level_one = df7.columns.get_level_values(1).astype(str)

# %%
df7.head()
# Out:
#                                      app_name    minutes
#                                                   median          std
# 0                  Amazon Mobile (Mobile App)    47.1555   311.223196
# 1  Amazon Music with Prime Music (Mobile App)    34.3980   449.620841
# 2                       Facebook (Mobile App)  2764.6542  3248.020616
# 3             Facebook Messenger (Mobile App)  1349.6490  3039.701650
# 4                    Google Play (Mobile App)    57.6639   548.827380

# %%
level_two = df7.columns.get_level_values(0).astype(str)

# %%
print(level_one)
# Out:
# Index(['', 'median', 'std'], dtype='object')

# %%
print(level_two)
# Out:
# Index(['app_name', 'minutes', 'minutes'], dtype='object')

# %%
df7.columns = level_one + level_two

# %%
df7.head(25)
# Out:
#                                       app_name  medianminutes   stdminutes
# 0                   Amazon Mobile (Mobile App)        47.1555   311.223196
# 1   Amazon Music with Prime Music (Mobile App)        34.3980   449.620841
# 2                        Facebook (Mobile App)      2764.6542  3248.020616
# 3              Facebook Messenger (Mobile App)      1349.6490  3039.701650
# 4                     Google Play (Mobile App)        57.6639   548.827380
# 5                   Google Search (Mobile App)       119.8638  1910.343859
# 6                         GroupMe (Mobile App)        64.6758   276.153920
# 7                       Instagram (Mobile App)       247.2498  1480.795910
# 8                          Kindle (Mobile App)        25.4394  1623.650743
# 9                  Microsoft Word (Mobile App)        11.6046    93.392425
# 10                        Netflix (Mobile App)        79.4934  2322.242635
# ...

# %%
# merged the stdminutes and medianmedian per app and our reference df with reference df on left .. we will use these medianminutes and stdminutes to perform filter later
df8 = pd.merge(df6,df7,on = ['app_name'],how = 'left')

# %%
df8.head()
# Out:
#     device_id                    app_name   minutes      Publisher  gender_id  \
# 0  B-52-23845       Snapchat (Mobile App)   27.9342  Snapchat, Inc        2.0
# 1  B-52-23845      Pinterest (Mobile App)    5.5188      Pinterest        2.0
# 2  B-52-23845      Instagram (Mobile App)  867.1320       Facebook        2.0
# 3  B-52-23845  Google Search (Mobile App)  236.8170   Google Sites        2.0
# 4  B-52-23845        YouTube (Mobile App)   69.6276   Google Sites        2.0
#
#    medianminutes   stdminutes
# 0       208.6182  1043.153679
# 1       104.1390   622.956328
# 2       247.2498  1480.795910
# 3       119.8638  1910.343859
# 4       209.8656  2294.867585

# %%
# checked if minutes > (stdminutes+medianminutes) or if less than 30 
boolean_series_3=(df8['minutes']>(df8['stdminutes'] + df8['medianminutes'])) | (df8['minutes']<30)

# %%
boolean_series_3.head(50)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20     True
# 21     True
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47    False
# 48    False
# 49     True
# dtype: bool

# %%
df8.iloc[6]
# Out:
# device_id                             B-52-23845
# app_name         Facebook Messenger (Mobile App)
# minutes                                3147.4548
# Publisher                               Facebook
# gender_id                                    2.0
# medianminutes                           1349.649
# stdminutes                            3039.70165
# Name: 6, dtype: object

# %%
# appended this boolean column here as we will filter only true conditions now which satisfy the equation 
df8['Boolean'] = boolean_series_3

# %%
df8.head(25)
# Out:
#      device_id                         app_name    minutes        Publisher  \
# 0   B-52-23845            Snapchat (Mobile App)    27.9342    Snapchat, Inc
# 1   B-52-23845           Pinterest (Mobile App)     5.5188        Pinterest
# 2   B-52-23845           Instagram (Mobile App)   867.1320         Facebook
# 3   B-52-23845       Google Search (Mobile App)   236.8170     Google Sites
# 4   B-52-23845             YouTube (Mobile App)    69.6276     Google Sites
# 5   B-52-23845              Tumblr (Mobile App)   184.8042             Oath
# 6   B-52-23845  Facebook Messenger (Mobile App)  3147.4548         Facebook
# 7   B-52-23845         Google Play (Mobile App)   311.7744     Google Sites
# 8    B-52-6821            Snapchat (Mobile App)    17.1990    Snapchat, Inc
# 9    B-52-6821           Pinterest (Mobile App)    68.6448        Pinterest
# 10   B-52-6821            Facebook (Mobile App)   629.5968         Facebook
# ...

# %%
df8.head()
# Out:
#     device_id                    app_name   minutes      Publisher  gender_id  \
# 0  B-52-23845       Snapchat (Mobile App)   27.9342  Snapchat, Inc        2.0
# 1  B-52-23845      Pinterest (Mobile App)    5.5188      Pinterest        2.0
# 2  B-52-23845      Instagram (Mobile App)  867.1320       Facebook        2.0
# 3  B-52-23845  Google Search (Mobile App)  236.8170   Google Sites        2.0
# 4  B-52-23845        YouTube (Mobile App)   69.6276   Google Sites        2.0
#
#    medianminutes   stdminutes  Boolean
# 0       208.6182  1043.153679     True
# 1       104.1390   622.956328     True
# 2       247.2498  1480.795910    False
# 3       119.8638  1910.343859    False
# 4       209.8656  2294.867585    False

# %%
# filtered data on boolean == True 
df8 = df8[df8['Boolean'] == True]

# %%
df8.head()
# Out:
#      device_id                app_name  minutes      Publisher  gender_id  \
# 0   B-52-23845   Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 1   B-52-23845  Pinterest (Mobile App)   5.5188      Pinterest        2.0
# 8    B-52-6821   Snapchat (Mobile App)  17.1990  Snapchat, Inc        2.0
# 11   B-52-6821    Netflix (Mobile App)   0.3024   Netflix Inc.        2.0
# 12   B-52-6821  Instagram (Mobile App)  27.5562       Facebook        2.0
#
#     medianminutes   stdminutes  Boolean
# 0        208.6182  1043.153679     True
# 1        104.1390   622.956328     True
# 8        208.6182  1043.153679     True
# 11        79.4934  2322.242635     True
# 12       247.2498  1480.795910     True

# %%
# resettind index as its all over the place  after filtering the data 
df8.reset_index()
# Out:
#       index   device_id                    app_name    minutes      Publisher  \
# 0         0  B-52-23845       Snapchat (Mobile App)    27.9342  Snapchat, Inc
# 1         1  B-52-23845      Pinterest (Mobile App)     5.5188      Pinterest
# 2         8   B-52-6821       Snapchat (Mobile App)    17.1990  Snapchat, Inc
# 3        11   B-52-6821        Netflix (Mobile App)     0.3024   Netflix Inc.
# 4        12   B-52-6821      Instagram (Mobile App)    27.5562       Facebook
# ...     ...         ...                         ...        ...            ...
# 8064  22434  B-52-13129    Google Play (Mobile App)    14.4018   Google Sites
# 8065  22435  B-52-44289    Google Play (Mobile App)     0.9072   Google Sites
# 8066  22436  B-52-44080    Google Play (Mobile App)  2097.8244   Google Sites
# 8067  22437  B-52-44099    Google Play (Mobile App)  1256.4720   Google Sites
# 8068  22439   B-52-1368  Amazon Mobile (Mobile App)   435.0780   Amazon Sites
#
# ...

# %%
# dropping these columns as they r not needed in final output 
df8.drop(['medianminutes','stdminutes','Boolean'],axis = 1 , inplace = True)

# %%
# transformation 4 output: 
df8.head()
# Out:
#      device_id                app_name  minutes      Publisher  gender_id
# 0   B-52-23845   Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 1   B-52-23845  Pinterest (Mobile App)   5.5188      Pinterest        2.0
# 8    B-52-6821   Snapchat (Mobile App)  17.1990  Snapchat, Inc        2.0
# 11   B-52-6821    Netflix (Mobile App)   0.3024   Netflix Inc.        2.0
# 12   B-52-6821  Instagram (Mobile App)  27.5562       Facebook        2.0

# %%
df8.reset_index(drop = True,inplace = True)

# %%
# performing regular checks 
df8.loc[df8['gender_id']==1]
# Out:
#        device_id                         app_name     minutes      Publisher  \
# 23    B-52-30153             YouTube (Mobile App)  10694.8296   Google Sites
# 24     B-52-2109            Snapchat (Mobile App)      1.0962  Snapchat, Inc
# 25     B-52-2109           Instagram (Mobile App)      0.0756       Facebook
# 26     B-52-2109         Google Play (Mobile App)      6.3882   Google Sites
# 27    B-52-51851       Google Search (Mobile App)      8.5806   Google Sites
# ...          ...                              ...         ...            ...
# 8049  B-52-13984         Google Play (Mobile App)      4.4982   Google Sites
# 8052  B-52-25954         Google Play (Mobile App)      4.3092   Google Sites
# 8053  B-52-23674             YouTube (Mobile App)   5752.9332   Google Sites
# 8054  B-52-23674  Facebook Messenger (Mobile App)   5419.6884       Facebook
# 8055  B-52-46892         Google Play (Mobile App)      1.5498   Google Sites
#
# ...

# %%
df8.head()
# Out:
#     device_id                app_name  minutes      Publisher  gender_id
# 0  B-52-23845   Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 1  B-52-23845  Pinterest (Mobile App)   5.5188      Pinterest        2.0
# 2   B-52-6821   Snapchat (Mobile App)  17.1990  Snapchat, Inc        2.0
# 3   B-52-6821    Netflix (Mobile App)   0.3024   Netflix Inc.        2.0
# 4   B-52-6821  Instagram (Mobile App)  27.5562       Facebook        2.0

# %%
# did transformation on point 9 and got point 10 after using describe and created a file as expected 
pd.DataFrame(df8.groupby('app_name')['minutes'].describe()).to_csv('app_data.csv')
# Out:
#                                             count         mean          std  \
# app_name
# Amazon Mobile (Mobile App)                  797.0   165.892485   434.931026
# Amazon Music with Prime Music (Mobile App)  169.0   209.322309   583.889715
# Facebook (Mobile App)                       545.0  7639.502902  4051.849091
# Facebook Messenger (Mobile App)             610.0  5697.830467  4486.578960
# Google Play (Mobile App)                    917.0   181.985070   938.763381
# Google Search (Mobile App)                  891.0   770.176612  3229.826022
# GroupMe (Mobile App)                         78.0   210.908492   393.856691
# Instagram (Mobile App)                      590.0  1608.812783  2244.278741
# Kindle (Mobile App)                         207.0   663.823148  2037.086012
# Microsoft Word (Mobile App)                 184.0    33.524902   101.614261
# Netflix (Mobile App)                        374.0  1183.853349  3321.724071
# ...

# %%
df6.loc[df6['minutes']==5009.7096]
# Out:
#         device_id                    app_name    minutes     Publisher  \
# 19683  B-52-12483  Amazon Mobile (Mobile App)  5009.7096  Amazon Sites
#
#        gender_id
# 19683        1.0

# %%
# confirming if the max column data we got in present in source file .. please note my data is not matching same as that of word file
# however i did see in word file there was file where minutes where > 30 which should not adhere to the filter condition . 
df.loc[df['minutes']==5009.7096]
# Out:
#        device_id                    app_name    minutes
# 3075  B-52-12483  Amazon Mobile (Mobile App)  5009.7096

# %%
df["minutes"] = pd.to_numeric(df["minutes"])

# %%
df.groupby('app_name')['minutes'].describe()
# Out:
#                                              count         mean          std  \
# app_name
# Amazon Mobile (Mobile App)                  1582.0   144.841619   315.026347
# Amazon Music with Prime Music (Mobile App)   287.0   187.148590   455.168903
# Facebook (Mobile App)                       2358.0  3612.205255  3310.483845
# Facebook Messenger (Mobile App)             2429.0  2478.538655  3089.771135
# Google Play (Mobile App)                    2674.0   148.563952   557.453830
# Google Search (Mobile App)                  2547.0   502.334796  1942.885503
# GroupMe (Mobile App)                         168.0   170.611425   277.777276
# Instagram (Mobile App)                      1618.0   890.798188  1504.660273
# Kindle (Mobile App)                          329.0   552.357383  1639.115962
# Microsoft Word (Mobile App)                  210.0    37.415700    95.441319
# Netflix (Mobile App)                         776.0   822.804047  2363.773317
# ...

# %%
df6.head()
# Out:
#     device_id                    app_name  minutes      Publisher  gender_id
# 0  B-52-23845       Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 1  B-52-23845      Pinterest (Mobile App)   5.5188      Pinterest        2.0
# 2  B-52-23845      Instagram (Mobile App)  867.132       Facebook        2.0
# 3  B-52-23845  Google Search (Mobile App)  236.817   Google Sites        2.0
# 4  B-52-23845        YouTube (Mobile App)  69.6276   Google Sites        2.0

# %%
Total_min_per_App =df8.groupby('app_name')['minutes'].sum()

# %%
Total_min_per_App.head()
Total_min_per_App = pd.DataFrame(Total_min_per_App)
Total_min_per_App.head()
# Out:
#                                                  minutes
# app_name
# Amazon Mobile (Mobile App)                  1.322163e+05
# Amazon Music with Prime Music (Mobile App)  3.537547e+04
# Facebook (Mobile App)                       4.163529e+06
# Facebook Messenger (Mobile App)             3.475677e+06
# Google Play (Mobile App)                    1.668803e+05

# %%
Total_device_per_App=df8.groupby('app_name')['device_id'].count()

# %%
Total_device_per_App.head()
# Out:
#                                             device_id
# app_name
# Amazon Mobile (Mobile App)                        797
# Amazon Music with Prime Music (Mobile App)        169
# Facebook (Mobile App)                             545
# Facebook Messenger (Mobile App)                   610
# Google Play (Mobile App)                          917

# %%
Total_device_per_App = pd.DataFrame(Total_device_per_App)

# %%
df9['total_devices'] = Total_device_per_App['device_id'].values
df9['total_devices'].head()
# Out:
# 0    797
# 1    169
# 2    545
# 3    610
# 4    917
# Name: total_devices, dtype: int64

# %%
df9 = pd.read_csv('app_data')

# %%
df9.head(25)
# Out:
#                                       app_name  count         mean  \
# 0                   Amazon Mobile (Mobile App)  797.0   165.892485
# 1   Amazon Music with Prime Music (Mobile App)  169.0   209.322309
# 2                        Facebook (Mobile App)  545.0  7639.502902
# 3              Facebook Messenger (Mobile App)  610.0  5697.830467
# 4                     Google Play (Mobile App)  917.0   181.985070
# 5                   Google Search (Mobile App)  891.0   770.176612
# 6                         GroupMe (Mobile App)   78.0   210.908492
# 7                       Instagram (Mobile App)  590.0  1608.812783
# 8                          Kindle (Mobile App)  207.0   663.823148
# 9                  Microsoft Word (Mobile App)  184.0    33.524902
# 10                        Netflix (Mobile App)  374.0  1183.853349
# 11                        Outlook (Mobile App)  122.0   425.715684
# 12                      Pinterest (Mobile App)  405.0   505.525253
# ...

# %%
df9['total_minutes'] = Total_min_per_App['minutes'].values

# %%
df9.head(25)
# Out:
#                                       app_name  count         mean  \
# 0                   Amazon Mobile (Mobile App)  797.0   165.892485
# 1   Amazon Music with Prime Music (Mobile App)  169.0   209.322309
# 2                        Facebook (Mobile App)  545.0  7639.502902
# 3              Facebook Messenger (Mobile App)  610.0  5697.830467
# 4                     Google Play (Mobile App)  917.0   181.985070
# 5                   Google Search (Mobile App)  891.0   770.176612
# 6                         GroupMe (Mobile App)   78.0   210.908492
# 7                       Instagram (Mobile App)  590.0  1608.812783
# 8                          Kindle (Mobile App)  207.0   663.823148
# 9                  Microsoft Word (Mobile App)  184.0    33.524902
# 10                        Netflix (Mobile App)  374.0  1183.853349
# 11                        Outlook (Mobile App)  122.0   425.715684
# 12                      Pinterest (Mobile App)  405.0   505.525253
# ...

# %%
df9.drop(['avg_time_spend_per_device'],axis = 1,inplace = True)

# %%
df10 = df9[['app_name','total_devices','total_minutes','mean']]

# %%
df10.head(25)
# Out:
#                                       app_name  total_devices  total_minutes  \
# 0                   Amazon Mobile (Mobile App)            797   1.322163e+05
# 1   Amazon Music with Prime Music (Mobile App)            169   3.537547e+04
# 2                        Facebook (Mobile App)            545   4.163529e+06
# 3              Facebook Messenger (Mobile App)            610   3.475677e+06
# 4                     Google Play (Mobile App)            917   1.668803e+05
# 5                   Google Search (Mobile App)            891   6.862274e+05
# 6                         GroupMe (Mobile App)             78   1.645086e+04
# 7                       Instagram (Mobile App)            590   9.491995e+05
# 8                          Kindle (Mobile App)            207   1.374114e+05
# 9                  Microsoft Word (Mobile App)            184   6.168582e+03
# 10                        Netflix (Mobile App)            374   4.427612e+05
# ...

# %%
df10.rename(columns = {'mean':'avg_time_spend_per_device'},inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df10.head()
# Out:
#                                      app_name  total_devices  total_minutes  \
# 0                  Amazon Mobile (Mobile App)            797   1.322163e+05
# 1  Amazon Music with Prime Music (Mobile App)            169   3.537547e+04
# 2                       Facebook (Mobile App)            545   4.163529e+06
# 3             Facebook Messenger (Mobile App)            610   3.475677e+06
# 4                    Google Play (Mobile App)            917   1.668803e+05
#
#    avg_time_spend_per_device  Rank(duration based)  Rank(user_based)
# 0                 165.892485                  10.0              18.0
# 1                 209.322309                   7.0               7.0
# 2                7639.502902                  21.0              15.0
# 3                5697.830467                  20.0              17.0
# 4                 181.985070                  13.0              21.0

# %%
df10["Rank(duration based)"] = df10["total_minutes"].rank(ascending = False)
# Out:
# <ipython-input-621-49e9a65d6a8c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10["Rank(duration based)"] = df10["total_minutes"].rank(ascending = False)

# %%
df10.head()
# Out:
#                                      app_name  total_devices  total_minutes  \
# 0                  Amazon Mobile (Mobile App)            797   1.322163e+05
# 1  Amazon Music with Prime Music (Mobile App)            169   3.537547e+04
# 2                       Facebook (Mobile App)            545   4.163529e+06
# 3             Facebook Messenger (Mobile App)            610   3.475677e+06
# 4                    Google Play (Mobile App)            917   1.668803e+05
#
#    avg_time_spend_per_device  Rank(duration based)  Rank(user_based)
# 0                 165.892485                  12.0              18.0
# 1                 209.322309                  15.0               7.0
# 2                7639.502902                   1.0              15.0
# 3                5697.830467                   2.0              17.0
# 4                 181.985070                   9.0              21.0

# %%
df10["Rank(user_based)"] = df10["total_devices"].rank(ascending = False)
# Out:
# <ipython-input-623-bb80f64a4c07>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10["Rank(user_based)"] = df10["total_devices"].rank(ascending = False)

# %%
df10.sort_values('Rank(user_based)')
# Out:
#                                       app_name  total_devices  total_minutes  \
# 4                     Google Play (Mobile App)            917   1.668803e+05
# 5                   Google Search (Mobile App)            891   6.862274e+05
# 20                        YouTube (Mobile App)            804   1.631514e+06
# 0                   Amazon Mobile (Mobile App)            797   1.322163e+05
# 3              Facebook Messenger (Mobile App)            610   3.475677e+06
# 7                       Instagram (Mobile App)            590   9.491995e+05
# 2                        Facebook (Mobile App)            545   4.163529e+06
# 15                       Snapchat (Mobile App)            494   5.331637e+05
# 17                        Walmart (Mobile App)            446   3.436572e+04
# 12                      Pinterest (Mobile App)            405   2.047377e+05
# 10                        Netflix (Mobile App)            374   4.427612e+05
# ...

# %%
df10.sort_values('Rank(user_based)').to_csv('app_user_based_ranking.csv')

# %%
df10.sort_values('Rank(duration based)')
# Out:
#                                       app_name  total_devices  total_minutes  \
# 2                        Facebook (Mobile App)            545   4.163529e+06
# 3              Facebook Messenger (Mobile App)            610   3.475677e+06
# 20                        YouTube (Mobile App)            804   1.631514e+06
# 7                       Instagram (Mobile App)            590   9.491995e+05
# 5                   Google Search (Mobile App)            891   6.862274e+05
# 15                       Snapchat (Mobile App)            494   5.331637e+05
# 10                        Netflix (Mobile App)            374   4.427612e+05
# 12                      Pinterest (Mobile App)            405   2.047377e+05
# 4                     Google Play (Mobile App)            917   1.668803e+05
# 18                     Yahoo Mail (Mobile App)            234   1.377956e+05
# 8                          Kindle (Mobile App)            207   1.374114e+05
# ...

# %%
df10.sort_values('Rank(duration based)').to_csv('Rank_User_Duration_based.csv')

# %%
 pd.DataFrame(df8.groupby('Publisher')['minutes'].describe()).to_csv('publisher_data.csv')

# %%
df11 = pd.read_csv('publisher_data.csv')

# %%
df11.head(25)
# Out:
#          Publisher   count         mean          std     min       25%  \
# 0     Amazon Sites  1173.0   260.019755   970.530751  0.0378   2.26800
# 1         Facebook  1745.0  4921.722183  4481.423470  0.0378  17.38800
# 2     Google Sites  2612.0   951.233425  2982.796933  0.0378   4.61160
# 3  Microsoft Sites   384.0   194.158223   528.833478  0.0756   3.50595
# 4     Netflix Inc.   374.0  1183.853349  3321.724071  0.0756   2.14515
# 5             Oath   349.0   698.196760  1761.338212  0.0378   2.91060
# 6        Pinterest   405.0   505.525253   900.992040  0.0378   2.49480
# 7    Snapchat, Inc   494.0  1079.278761  1551.793354  0.0756   6.35985
# 8         Wal-Mart   533.0    69.586219   152.401276  0.0378   4.38480
#
#          50%         75%         max
# 0     8.5050    24.38100  14741.0928
# 1  5161.0230  7697.81880  25093.9080
# 2    13.8726    26.20485  50897.4354
# 3    11.6046    26.04420   5977.8432
# 4     7.9569    24.99525  29667.4812
# ...

# %%
Total_min_per_pub =df8.groupby('Publisher')['minutes'].sum()
Total_min_per_pub.head()
Total_min_per_pub = pd.DataFrame(Total_min_per_pub)
Total_min_per_pub.head(24)
# Out:
#                       minutes
# Publisher
# Amazon Sites     3.050032e+05
# Facebook         8.588405e+06
# Google Sites     2.484622e+06
# Microsoft Sites  7.455676e+04
# Netflix Inc.     4.427612e+05
# Oath             2.436707e+05
# Pinterest        2.047377e+05
# Snapchat, Inc    5.331637e+05
# Wal-Mart         3.708945e+04

# %%
Total_device_per_pub=df8.groupby('Publisher')['device_id'].count()
Total_device_per_pub.head()
# Out:
# Publisher
# Amazon Sites       1173
# Facebook           1745
# Google Sites       2612
# Microsoft Sites     384
# Netflix Inc.        374
# Name: device_id, dtype: int64

# %%
Total_device_per_pub = pd.DataFrame(Total_device_per_pub)
Total_device_per_pub.head(25)
# Out:
#                  device_id
# Publisher
# Amazon Sites          1173
# Facebook              1745
# Google Sites          2612
# Microsoft Sites        384
# Netflix Inc.           374
# Oath                   349
# Pinterest              405
# Snapchat, Inc          494
# Wal-Mart               533

# %%
df11['total_minutes'] = Total_min_per_pub['minutes'].values

# %%
df11['total_users'] = Total_device_per_pub['device_id'].values

# %%
df11.head()
# Out:
#          Publisher   count         mean          std     min       25%  \
# 0     Amazon Sites  1173.0   260.019755   970.530751  0.0378   2.26800
# 1         Facebook  1745.0  4921.722183  4481.423470  0.0378  17.38800
# 2     Google Sites  2612.0   951.233425  2982.796933  0.0378   4.61160
# 3  Microsoft Sites   384.0   194.158223   528.833478  0.0756   3.50595
# 4     Netflix Inc.   374.0  1183.853349  3321.724071  0.0756   2.14515
#
#          50%         75%         max  total_minutes  total_users
# 0     8.5050    24.38100  14741.0928   3.050032e+05         1173
# 1  5161.0230  7697.81880  25093.9080   8.588405e+06         1745
# 2    13.8726    26.20485  50897.4354   2.484622e+06         2612
# 3    11.6046    26.04420   5977.8432   7.455676e+04          384
# 4     7.9569    24.99525  29667.4812   4.427612e+05          374

# %%
df12 = df11[['Publisher','total_users','total_minutes','mean']]

# %%
df12.head(25)
# Out:
#          Publisher  total_users  total_minutes         mean
# 0     Amazon Sites         1173   3.050032e+05   260.019755
# 1         Facebook         1745   8.588405e+06  4921.722183
# 2     Google Sites         2612   2.484622e+06   951.233425
# 3  Microsoft Sites          384   7.455676e+04   194.158223
# 4     Netflix Inc.          374   4.427612e+05  1183.853349
# 5             Oath          349   2.436707e+05   698.196760
# 6        Pinterest          405   2.047377e+05   505.525253
# 7    Snapchat, Inc          494   5.331637e+05  1079.278761
# 8         Wal-Mart          533   3.708945e+04    69.586219

# %%
df12["Rank(duration based)"] = df12["total_minutes"].rank(ascending = False)
df12["Rank(users based)"] = df12["total_users"].rank(ascending = False)
# Out:
# <ipython-input-655-13cc9472980f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12["Rank(duration based)"] = df12["total_minutes"].rank(ascending = False)
# <ipython-input-655-13cc9472980f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12["Rank(users based)"] = df12["total_users"].rank(ascending = False)

# %%
df12.head()
# Out:
#          Publisher  total_users  total_minutes         mean  \
# 0     Amazon Sites         1173   3.050032e+05   260.019755
# 1         Facebook         1745   8.588405e+06  4921.722183
# 2     Google Sites         2612   2.484622e+06   951.233425
# 3  Microsoft Sites          384   7.455676e+04   194.158223
# 4     Netflix Inc.          374   4.427612e+05  1183.853349
#
#    Rank(duration based)  Rank(users based)
# 0                   5.0                3.0
# 1                   1.0                2.0
# 2                   2.0                1.0
# 3                   8.0                7.0
# 4                   4.0                8.0

# %%
df12[['Publisher','total_users','Rank(users based)']].sort_values('Rank(users based)').to_csv('Rank_Publishers_Users.csv')

# %%
df12[['Publisher','total_minutes','Rank(duration based)']].sort_values('Rank(duration based)').to_csv('Rank_Publishers_duration.csv')

# %%
import matplotlib.pyplot as plt
df6.head()
# Out:
#     device_id                    app_name   minutes      Publisher  gender_id
# 0  B-52-23845       Snapchat (Mobile App)   27.9342  Snapchat, Inc        2.0
# 1  B-52-23845      Pinterest (Mobile App)    5.5188      Pinterest        2.0
# 2  B-52-23845      Instagram (Mobile App)  867.1320       Facebook        2.0
# 3  B-52-23845  Google Search (Mobile App)  236.8170   Google Sites        2.0
# 4  B-52-23845        YouTube (Mobile App)   69.6276   Google Sites        2.0

# %%
#df6.groupby('app_name').agg({'minutes':['median']})
df13 = df6.groupby('app_name',as_index = False).agg({'minutes':['mean']})

# %%
df13.head()
# Out:
#                                      app_name      minutes
#                                                       mean
# 0                  Amazon Mobile (Mobile App)   142.256694
# 1  Amazon Music with Prime Music (Mobile App)   183.006201
# 2                       Facebook (Mobile App)  3579.664496
# 3             Facebook Messenger (Mobile App)  2436.910289
# 4                    Google Play (Mobile App)   145.699662

# %%
df13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   app_name     21 non-null     object
#  1   meanminutes  21 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 504.0+ bytes

# %%
level_one = df13.columns.get_level_values(1).astype(str)
level_two = df13.columns.get_level_values(0).astype(str)
df13.columns = level_one + level_two

# %%
df13.head()
data = df13.groupby("app_name")["meanminutes"].sum()

# %%
data.head()
# Out:
# app_name
# Amazon Mobile (Mobile App)                     142.256694
# Amazon Music with Prime Music (Mobile App)     183.006201
# Facebook (Mobile App)                         3579.664496
# Facebook Messenger (Mobile App)               2436.910289
# Google Play (Mobile App)                       145.699662
# Name: meanminutes, dtype: float64

# %%
data.plot.pie(autopct="%.1f%%");

# %%
pie, ax = plt.subplots(figsize=[30,15])
labels = data.keys()
plt.pie(x=data, autopct="%.1f%%", labels=labels, pctdistance=0.5)
plt.title("% of users per app", fontsize=14);

# %%
data2 = df6.groupby(["app_name","gender_id"])["device_id"].count()

# %%
data2.head(50)
# Out:
# app_name                                    gender_id
# Amazon Mobile (Mobile App)                  1.0           602
#                                             2.0          1023
# Amazon Music with Prime Music (Mobile App)  1.0            96
#                                             2.0           199
# Facebook (Mobile App)                       1.0           897
#                                             2.0          1558
# Facebook Messenger (Mobile App)             1.0           910
#                                             2.0          1612
# Google Play (Mobile App)                    1.0          1015
#                                             2.0          1746
# Google Search (Mobile App)                  1.0           966
#                                             2.0          1672
# GroupMe (Mobile App)                        1.0            56
#                                             2.0           114
# ...

# %%
import seaborn as sns
plt.figure(figsize = (20,10))
ax = sns.countplot(y="app_name", hue="gender_id", data=df6)
ax.set_title("gender vs app_name", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'gender vs app_name')
